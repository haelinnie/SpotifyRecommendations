# %% [markdown]
# # Spotify Recommendations

# %% [markdown]
# In this project, we're going to be building a prediction model that classifies what songs we like in a given playlist. Our goal is to create a new playlist with these recommended songs.

# %% [markdown]
# ## Setting Up

# %% [markdown]
# First and foremost, we need to set up by importing our libraries we will be using and using Spotify's Web API (https://developer.spotify.com/dashboard/login). After creating an application to use the API, authorize and login to your Spotify account.

# %%
#import pandas, numpy, spotipy, seaborn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

# %%
#let's login and authorize
client ='c87ccfa6cec94d899bdb886a36eafc65'
secret = '561c2cf43b3f472bb22746963b8c8972'
username = '1235663476'
redirect_uri='https://developer.spotify.com/dashboard/applications/c87ccfa6cec94d899bdb886a36eafc65'

#https://developer.spotify.com/documentation/general/guides/scopes/#playlist-modify-private
#I'll be accessing a private playlist, and creating a public playlist with my recommendations
scope = 'user-library-read playlist-modify-public playlist-read-private'

#DO NOT CHANGE
client_credentials_manager = SpotifyClientCredentials(client_id = client, client_secret = secret) 
sp = spotipy.Spotify(client_credentials_manager =  client_credentials_manager)
token = util.prompt_for_user_token(username, scope, client, secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %% [markdown]
# Now that we're authorized, let's load our playlists into some pandas dataframes! Let's get features from our spotify playlist and get the traits of these tracks. Each track has various audio features like liveness, acoustics, energy, danceability, tempo, etc. We will be using these features to run our model. Here's a list of these features: https://developer.spotify.com/documentation/web-api/reference/object-model/#audio-features-object
#
#
# Helpful link to functions we can use in Spotipy: https://spotipy.readthedocs.io/en/latest/#features

# %%
def create_df(userID, playlistID):
    #load our playlist
    good_playlist = sp.user_playlist(userID, playlistID)
    songs = good_playlist["tracks"]["items"]

    #create an array of track ids (to find audio features) and create an array of song names
    track_ids = []
    song_names = []
    for i in songs:
        track_ids.append(i["track"]["id"])
        song_names.append(i["track"]["name"])

    #loop through to get audio features
    features = []
    for i in track_ids:
        for track in sp.audio_features(i):
            features.append(track)

    df = pd.DataFrame(features, index = song_names)
    return df

# %% [markdown]
# Now that we have a function that can create a pandas dataframe of a playlist's audio features, let's crceate a two dataframes. One will be a "good" set with all the songs we like. The other will be a "bad" set with songs we dislike.

# %%
good_id = '7umNGrCO2vgK5DCOadw8t1?si=U0x18FqkQvuIWC_f2xUWqg'
good_df = create_df(username, good_id)
good_df.head()
# Out:
#                                    acousticness  \
# Plastic (Mid-City Island Version)        0.7410
# Fantasy                                  0.3550
# Sunday Candy                             0.5300
# Lemonade - Ukulele Version               0.8680
# Chivalry Is Dead                         0.0214
#
#                                                                         analysis_url  \
# Plastic (Mid-City Island Version)  https://api.spotify.com/v1/audio-analysis/57K5...
# Fantasy                            https://api.spotify.com/v1/audio-analysis/6M8R...
# Sunday Candy                       https://api.spotify.com/v1/audio-analysis/6fTd...
# Lemonade - Ukulele Version         https://api.spotify.com/v1/audio-analysis/4Cr5...
# Chivalry Is Dead                   https://api.spotify.com/v1/audio-analysis/6kOr...
#
#                                    danceability  duration_ms  energy  \
# Plastic (Mid-City Island Version)         0.457       157199   0.275
# Fantasy                                   0.686       218947   0.755
# Sunday Candy                              0.511       226014   0.596
# Lemonade - Ukulele Version                0.546       181505   0.221
# Chivalry Is Dead                          0.690       209446   0.732
#
#                                                        id  instrumentalness  \
# Plastic (Mid-City Island Version)  57K5RyWj4jOlc07wRz6axh               0.0
# Fantasy                            6M8R1IOnnbtKBogIs6uqRF               0.0
# Sunday Candy                       6fTdcGsjxlAD9PSkoPaLMX               0.0
# Lemonade - Ukulele Version         4Cr5ZdbgntUlinyEfrFYIl               0.0
# Chivalry Is Dead                   6kOrmPz9pkGzL4umBBRmWy               0.0
#
#                                    key  liveness  loudness  mode  speechiness  \
# Plastic (Mid-City Island Version)   11    0.1150   -12.553     1       0.0468
# Fantasy                              4    0.1380    -6.213     0       0.0916
# Sunday Candy                         0    0.0798    -6.560     1       0.2240
# Lemonade - Ukulele Version           2    0.0994    -8.915     1       0.0630
# Chivalry Is Dead                     6    0.0579    -5.499     1       0.0444
#
#                                      tempo  time_signature  \
# Plastic (Mid-City Island Version)  120.044               4
# Fantasy                            113.860               4
# Sunday Candy                       158.063               4
# Lemonade - Ukulele Version         128.144               4
# Chivalry Is Dead                   129.875               4
#
#                                                                           track_href  \
# Plastic (Mid-City Island Version)  https://api.spotify.com/v1/tracks/57K5RyWj4jOl...
# Fantasy                            https://api.spotify.com/v1/tracks/6M8R1IOnnbtK...
# Sunday Candy                       https://api.spotify.com/v1/tracks/6fTdcGsjxlAD...
# Lemonade - Ukulele Version         https://api.spotify.com/v1/tracks/4Cr5ZdbgntUl...
# Chivalry Is Dead                   https://api.spotify.com/v1/tracks/6kOrmPz9pkGz...
#
#                                              type  \
# Plastic (Mid-City Island Version)  audio_features
# Fantasy                            audio_features
# Sunday Candy                       audio_features
# Lemonade - Ukulele Version         audio_features
# Chivalry Is Dead                   audio_features
#
#                                                                     uri  \
# Plastic (Mid-City Island Version)  spotify:track:57K5RyWj4jOlc07wRz6axh
# Fantasy                            spotify:track:6M8R1IOnnbtKBogIs6uqRF
# Sunday Candy                       spotify:track:6fTdcGsjxlAD9PSkoPaLMX
# Lemonade - Ukulele Version         spotify:track:4Cr5ZdbgntUlinyEfrFYIl
# Chivalry Is Dead                   spotify:track:6kOrmPz9pkGzL4umBBRmWy
#
#                                    valence
# Plastic (Mid-City Island Version)    0.180
# Fantasy                              0.344
# Sunday Candy                         0.554
# Lemonade - Ukulele Version           0.593
# Chivalry Is Dead                     0.661

# %%
bad_id = '74EBZChFKDeVVHpaoTQQcj?si=LjU_FhXESQC_0prqF36eyA'
bad_df = create_df(username, bad_id)
bad_df.head()
# Out:
#                               acousticness  \
# Bouncin                            0.31400
# Throwin' Elbows                    0.00314
# All Star                           0.03190
# Seven Million (feat. Future)       0.05100
# through the late night             0.36000
#
#                                                                    analysis_url  \
# Bouncin                       https://api.spotify.com/v1/audio-analysis/0BEa...
# Throwin' Elbows               https://api.spotify.com/v1/audio-analysis/6srT...
# All Star                      https://api.spotify.com/v1/audio-analysis/3cfO...
# Seven Million (feat. Future)  https://api.spotify.com/v1/audio-analysis/6j0t...
# through the late night        https://api.spotify.com/v1/audio-analysis/1Ci4...
#
#                               danceability  duration_ms  energy  \
# Bouncin                              0.713       195429   0.611
# Throwin' Elbows                      0.580       182400   0.940
# All Star                             0.731       200373   0.861
# Seven Million (feat. Future)         0.886       182491   0.629
# through the late night               0.744       286236   0.589
#
#                                                   id  instrumentalness  key  \
# Bouncin                       0BEaYkPp5PnclzQxbNgwmM          0.000000    1
# Throwin' Elbows               6srThv0baveLRq4do7nRGB          0.042600    2
# All Star                      3cfOd4CMv2snFaKAnMdnvK          0.000000   11
# Seven Million (feat. Future)  6j0teRL3WdExzqmy334sh5          0.000008    1
# through the late night        1Ci4wASMY4xtKVMeHA6Sd5          0.000000    5
#
#                               liveness  loudness  mode  speechiness    tempo  \
# Bouncin                         0.1170    -6.702     0       0.2410  140.061
# Throwin' Elbows                 0.1130    -3.038     1       0.5670  149.990
# All Star                        0.0829    -5.881     1       0.0323  104.034
# Seven Million (feat. Future)    0.1210    -4.404     0       0.3060  158.002
# through the late night          0.1190    -1.218     0       0.0359  127.051
#
#                               time_signature  \
# Bouncin                                    4
# Throwin' Elbows                            4
# All Star                                   4
# Seven Million (feat. Future)               4
# through the late night                     4
#
#                                                                      track_href  \
# Bouncin                       https://api.spotify.com/v1/tracks/0BEaYkPp5Pnc...
# Throwin' Elbows               https://api.spotify.com/v1/tracks/6srThv0baveL...
# All Star                      https://api.spotify.com/v1/tracks/3cfOd4CMv2sn...
# Seven Million (feat. Future)  https://api.spotify.com/v1/tracks/6j0teRL3WdEx...
# through the late night        https://api.spotify.com/v1/tracks/1Ci4wASMY4xt...
#
#                                         type  \
# Bouncin                       audio_features
# Throwin' Elbows               audio_features
# All Star                      audio_features
# Seven Million (feat. Future)  audio_features
# through the late night        audio_features
#
#                                                                uri  valence
# Bouncin                       spotify:track:0BEaYkPp5PnclzQxbNgwmM    0.793
# Throwin' Elbows               spotify:track:6srThv0baveLRq4do7nRGB    0.362
# All Star                      spotify:track:3cfOd4CMv2snFaKAnMdnvK    0.780
# Seven Million (feat. Future)  spotify:track:6j0teRL3WdExzqmy334sh5    0.487
# through the late night        spotify:track:1Ci4wASMY4xtKVMeHA6Sd5    0.242

# %% [markdown]
# ## Cleaning and Visualizing

# %% [markdown]
# So now that we have our dataframes, we can see there are some features we don't really need for building our model. These features are things like ID or URI, which act more as identification rather than add musical value. We want features that are about the music so let's remove these columns!

# %%
good_df = good_df.drop(columns=["analysis_url", "id", "track_href", "type", "uri"])
bad_df = bad_df.drop(columns=["analysis_url", "id", "track_href", "type", "uri"])

# %% [markdown]
# Let's use seaborn displot to see some histograms to compare how the features differ when we like vs. dislike a song!

# %%
sns.distplot(good_df["acousticness"], color='b', label="likes")
sns.distplot(bad_df["acousticness"], color='r', label="dislikes").set_title("Acoustics")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(good_df["loudness"], color='b', label="likes")
sns.distplot(bad_df["loudness"], color='r', label="dislikes").set_title("Loudness")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(good_df["tempo"], color='b', label="likes")
sns.distplot(bad_df["tempo"], color='r', label="dislikes").set_title("Tempo")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(good_df["time_signature"], color='b', label="likes")
sns.distplot(bad_df["time_signature"], color='r', label="dislikes").set_title("Tempo")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(good_df["energy"], color='b', label="likes", bins= 20)
sns.distplot(bad_df["energy"], color='r', label="dislikes", bins = 20).set_title("Energy")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## Other Features and Columns

# %% [markdown]
# Let's add on other features that can possibily be useful  for our model. One feature I will look it is popularity. First, let's extract a song's popularity rating. Then, let's compare to see if popularity truly does differ between songs I like and dislike.

# %%
good_playlist = sp.user_playlist(username, '7umNGrCO2vgK5DCOadw8t1?si=U0x18FqkQvuIWC_f2xUWqg')
good_songs = good_playlist["tracks"]["items"]
good_popularity = []
for i in good_songs:
    good_popularity.append(i["track"]["popularity"])

# %%
bad_playlist = sp.user_playlist(username, '74EBZChFKDeVVHpaoTQQcj?si=LjU_FhXESQC_0prqF36eyA')
bad_songs = bad_playlist["tracks"]["items"]
bad_popularity = []
for i in bad_songs:
    bad_popularity.append(i["track"]["popularity"])
    
len(bad_popularity)
#len(bad_df)
# Out:
# 82

# %% [markdown]
# Let's add these new features to our dataframe columns

# %%
good_df["popularity"] = good_popularity
good_df.head()
# Out:
#                                    acousticness  danceability  duration_ms  \
# Plastic (Mid-City Island Version)        0.7410         0.457       157199
# Fantasy                                  0.3550         0.686       218947
# Sunday Candy                             0.5300         0.511       226014
# Lemonade - Ukulele Version               0.8680         0.546       181505
# Chivalry Is Dead                         0.0214         0.690       209446
#
#                                    energy  instrumentalness  key  liveness  \
# Plastic (Mid-City Island Version)   0.275               0.0   11    0.1150
# Fantasy                             0.755               0.0    4    0.1380
# Sunday Candy                        0.596               0.0    0    0.0798
# Lemonade - Ukulele Version          0.221               0.0    2    0.0994
# Chivalry Is Dead                    0.732               0.0    6    0.0579
#
#                                    loudness  mode  speechiness    tempo  \
# Plastic (Mid-City Island Version)   -12.553     1       0.0468  120.044
# Fantasy                              -6.213     0       0.0916  113.860
# Sunday Candy                         -6.560     1       0.2240  158.063
# Lemonade - Ukulele Version           -8.915     1       0.0630  128.144
# Chivalry Is Dead                     -5.499     1       0.0444  129.875
#
#                                    time_signature  valence  popularity
# Plastic (Mid-City Island Version)               4    0.180          52
# Fantasy                                         4    0.344          47
# Sunday Candy                                    4    0.554          68
# Lemonade - Ukulele Version                      4    0.593           3
# Chivalry Is Dead                                4    0.661           0

# %%
bad_df["popularity"] = bad_popularity
bad_df.head()
# Out:
#                               acousticness  danceability  duration_ms  energy  \
# Bouncin                            0.31400         0.713       195429   0.611
# Throwin' Elbows                    0.00314         0.580       182400   0.940
# All Star                           0.03190         0.731       200373   0.861
# Seven Million (feat. Future)       0.05100         0.886       182491   0.629
# through the late night             0.36000         0.744       286236   0.589
#
#                               instrumentalness  key  liveness  loudness  mode  \
# Bouncin                               0.000000    1    0.1170    -6.702     0
# Throwin' Elbows                       0.042600    2    0.1130    -3.038     1
# All Star                              0.000000   11    0.0829    -5.881     1
# Seven Million (feat. Future)          0.000008    1    0.1210    -4.404     0
# through the late night                0.000000    5    0.1190    -1.218     0
#
#                               speechiness    tempo  time_signature  valence  \
# Bouncin                            0.2410  140.061               4    0.793
# Throwin' Elbows                    0.5670  149.990               4    0.362
# All Star                           0.0323  104.034               4    0.780
# Seven Million (feat. Future)       0.3060  158.002               4    0.487
# through the late night             0.0359  127.051               4    0.242
#
#                               popularity
# Bouncin                               50
# Throwin' Elbows                       54
# All Star                              79
# Seven Million (feat. Future)          63
# through the late night                69

# %%
sns.distplot(good_df["popularity"], color='b', label="likes")
sns.distplot(bad_df["popularity"], color='r', label="dislikes").set_title("Popularity")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
