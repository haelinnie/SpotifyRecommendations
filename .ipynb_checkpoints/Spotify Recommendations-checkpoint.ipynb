# %% [markdown]
# # Spotify Recommendations

# %% [markdown]
# In this project, we're going to be building a prediction model that classifies what songs we like in a given playlist. Our goal is to create a new playlist with these recommended songs.

# %% [markdown]
# ## Setting Up

# %% [markdown]
# First and foremost, we need to set up by importing our libraries we will be using and using Spotify's Web API (https://developer.spotify.com/dashboard/login). After creating an application to use the API, authorize and login to your Spotify account.

# %%
#import pandas, numpy, spotipy, seaborn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

# %%
#let's login and authorize
client ='c87ccfa6cec94d899bdb886a36eafc65'
secret = '561c2cf43b3f472bb22746963b8c8972'
username = '1235663476'
redirect_uri='https://developer.spotify.com/dashboard/applications/c87ccfa6cec94d899bdb886a36eafc65'

#https://developer.spotify.com/documentation/general/guides/scopes/#playlist-modify-private
#I'll be accessing a private playlist, and creating a public playlist with my recommendations
scope = 'user-library-read playlist-modify-public playlist-read-private'

#DO NOT CHANGE
client_credentials_manager = SpotifyClientCredentials(client_id = client, client_secret = secret) 
sp = spotipy.Spotify(client_credentials_manager =  client_credentials_manager)
token = util.prompt_for_user_token(username, scope, client, secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %% [markdown]
# Now that we're authorized, let's load our playlists into some pandas dataframes! Let's get features from our spotify playlist and get the traits of these tracks. Each track has various audio features like liveness, acoustics, energy, danceability, tempo, etc. We will be using these features to run our model. Here's a list of these features: https://developer.spotify.com/documentation/web-api/reference/object-model/#audio-features-object
#
#
# Helpful link to functions we can use in Spotipy: https://spotipy.readthedocs.io/en/latest/#features

# %%
def create_df(userID, playlistID):
    #load our playlist
    good_playlist = sp.user_playlist(userID, playlistID)
    songs = good_playlist["tracks"]["items"]

    #create an array of track ids (to find audio features) and create an array of song names
    track_ids = []
    song_names = []
    for i in songs:
        track_ids.append(i["track"]["id"])
        song_names.append(i["track"]["name"])

    #loop through to get audio features
    features = []
    for i in track_ids:
        for track in sp.audio_features(i):
            features.append(track)

    df = pd.DataFrame(features, index = song_names)
    return df

# %% [markdown]
# Now that we have a function that can create a pandas dataframe of a playlist's audio features, let's crceate a two dataframes. One will be a "good" set with all the songs we like. The other will be a "bad" set with songs we dislike.

# %%
good_id = '7umNGrCO2vgK5DCOadw8t1?si=U0x18FqkQvuIWC_f2xUWqg'
good_df = create_df(username, good_id)
good_df.head()
# Out:
#                        acousticness  \
# Day 1 ◑                       0.210
# Midsummer Madness             0.359
# I Like U                      0.071
# Paris in the Rain             0.771
# Heebiejeebies - Bonus         0.419
#
#                                                             analysis_url  \
# Day 1 ◑                https://api.spotify.com/v1/audio-analysis/6ZzY...
# Midsummer Madness      https://api.spotify.com/v1/audio-analysis/6Tod...
# I Like U               https://api.spotify.com/v1/audio-analysis/6pAC...
# Paris in the Rain      https://api.spotify.com/v1/audio-analysis/41Cg...
# Heebiejeebies - Bonus  https://api.spotify.com/v1/audio-analysis/32xx...
#
#                        danceability  duration_ms  energy  \
# Day 1 ◑                       0.503       233601   0.581
# Midsummer Madness             0.409       280842   0.678
# I Like U                      0.480       267733   0.526
# Paris in the Rain             0.426       204712   0.408
# Heebiejeebies - Bonus         0.766       220160   0.500
#
#                                            id  instrumentalness  key  \
# Day 1 ◑                6ZzYETKetIfNUsZUb23jgG          0.000708    6
# Midsummer Madness      6TodWdTSDfzwgYynTZSvJn          0.000005    9
# I Like U               6pAC6ykvbcetfLl9pMQ97v          0.000000    5
# Paris in the Rain      41CgzGD7xlgnJe14R4cqkL          0.000008    3
# Heebiejeebies - Bonus  32xx0fAv3CIeGmNaWTHvEF          0.000000    1
#
#                        liveness  loudness  mode  speechiness    tempo  \
# Day 1 ◑                  0.2570    -7.007     1       0.0881   94.555
# Midsummer Madness        0.1670    -7.731     1       0.0878   89.968
# I Like U                 0.0879    -7.099     1       0.2750  199.662
# Paris in the Rain        0.3940    -9.419     1       0.0524   76.309
# Heebiejeebies - Bonus    0.1080    -7.626     1       0.1520  107.045
#
#                        time_signature  \
# Day 1 ◑                             4
# Midsummer Madness                   4
# I Like U                            3
# Paris in the Rain                   4
# Heebiejeebies - Bonus               4
#
#                                                               track_href  \
# Day 1 ◑                https://api.spotify.com/v1/tracks/6ZzYETKetIfN...
# Midsummer Madness      https://api.spotify.com/v1/tracks/6TodWdTSDfzw...
# I Like U               https://api.spotify.com/v1/tracks/6pAC6ykvbcet...
# Paris in the Rain      https://api.spotify.com/v1/tracks/41CgzGD7xlgn...
# Heebiejeebies - Bonus  https://api.spotify.com/v1/tracks/32xx0fAv3CIe...
#
#                                  type                                   uri  \
# Day 1 ◑                audio_features  spotify:track:6ZzYETKetIfNUsZUb23jgG
# Midsummer Madness      audio_features  spotify:track:6TodWdTSDfzwgYynTZSvJn
# I Like U               audio_features  spotify:track:6pAC6ykvbcetfLl9pMQ97v
# Paris in the Rain      audio_features  spotify:track:41CgzGD7xlgnJe14R4cqkL
# Heebiejeebies - Bonus  audio_features  spotify:track:32xx0fAv3CIeGmNaWTHvEF
#
#                        valence
# Day 1 ◑                  0.633
# Midsummer Madness        0.168
# I Like U                 0.374
# Paris in the Rain        0.528
# Heebiejeebies - Bonus    0.495

# %%
bad_id = '74EBZChFKDeVVHpaoTQQcj?si=LjU_FhXESQC_0prqF36eyA'
bad_df = create_df(username, bad_id)
bad_df.head()
# Out:
#                               acousticness  \
# Bouncin                            0.31400
# Throwin' Elbows                    0.00314
# All Star                           0.03190
# Seven Million (feat. Future)       0.05100
# through the late night             0.36000
#
#                                                                    analysis_url  \
# Bouncin                       https://api.spotify.com/v1/audio-analysis/0BEa...
# Throwin' Elbows               https://api.spotify.com/v1/audio-analysis/6srT...
# All Star                      https://api.spotify.com/v1/audio-analysis/3cfO...
# Seven Million (feat. Future)  https://api.spotify.com/v1/audio-analysis/6j0t...
# through the late night        https://api.spotify.com/v1/audio-analysis/1Ci4...
#
#                               danceability  duration_ms  energy  \
# Bouncin                              0.713       195429   0.611
# Throwin' Elbows                      0.580       182400   0.940
# All Star                             0.731       200373   0.861
# Seven Million (feat. Future)         0.886       182491   0.629
# through the late night               0.744       286236   0.589
#
#                                                   id  instrumentalness  key  \
# Bouncin                       0BEaYkPp5PnclzQxbNgwmM          0.000000    1
# Throwin' Elbows               6srThv0baveLRq4do7nRGB          0.042600    2
# All Star                      3cfOd4CMv2snFaKAnMdnvK          0.000000   11
# Seven Million (feat. Future)  6j0teRL3WdExzqmy334sh5          0.000008    1
# through the late night        1Ci4wASMY4xtKVMeHA6Sd5          0.000000    5
#
#                               liveness  loudness  mode  speechiness    tempo  \
# Bouncin                         0.1170    -6.702     0       0.2410  140.061
# Throwin' Elbows                 0.1130    -3.038     1       0.5670  149.990
# All Star                        0.0829    -5.881     1       0.0323  104.034
# Seven Million (feat. Future)    0.1210    -4.404     0       0.3060  158.002
# through the late night          0.1190    -1.218     0       0.0359  127.051
#
#                               time_signature  \
# Bouncin                                    4
# Throwin' Elbows                            4
# All Star                                   4
# Seven Million (feat. Future)               4
# through the late night                     4
#
#                                                                      track_href  \
# Bouncin                       https://api.spotify.com/v1/tracks/0BEaYkPp5Pnc...
# Throwin' Elbows               https://api.spotify.com/v1/tracks/6srThv0baveL...
# All Star                      https://api.spotify.com/v1/tracks/3cfOd4CMv2sn...
# Seven Million (feat. Future)  https://api.spotify.com/v1/tracks/6j0teRL3WdEx...
# through the late night        https://api.spotify.com/v1/tracks/1Ci4wASMY4xt...
#
#                                         type  \
# Bouncin                       audio_features
# Throwin' Elbows               audio_features
# All Star                      audio_features
# Seven Million (feat. Future)  audio_features
# through the late night        audio_features
#
#                                                                uri  valence
# Bouncin                       spotify:track:0BEaYkPp5PnclzQxbNgwmM    0.793
# Throwin' Elbows               spotify:track:6srThv0baveLRq4do7nRGB    0.362
# All Star                      spotify:track:3cfOd4CMv2snFaKAnMdnvK    0.780
# Seven Million (feat. Future)  spotify:track:6j0teRL3WdExzqmy334sh5    0.487
# through the late night        spotify:track:1Ci4wASMY4xtKVMeHA6Sd5    0.242

# %% [markdown]
# ## Cleaning and Visualizing

# %% [markdown]
# So now that we have our dataframes, we can see there are some features we don't really need for building our model. These features are things like ID or URI, which act more as identification rather than add musical value. We want features that are about the music so let's remove these columns!

# %%
good_df = good_df.drop(columns=["analysis_url", "id", "track_href", "type", "uri"])
bad_df = bad_df.drop(columns=["analysis_url", "id", "track_href", "type", "uri"])

# %% [markdown]
# Let's use seaborn displot to see some histograms to compare how the features differ when we like vs. dislike a song!

# %%
sns.distplot(good_df["acousticness"], color='b', label="likes")
sns.distplot(bad_df["acousticness"], color='r', label="dislikes").set_title("Acoustics")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(good_df["loudness"], color='b', label="likes")
sns.distplot(bad_df["loudness"], color='r', label="dislikes").set_title("Loudness")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(good_df["tempo"], color='b', label="likes")
sns.distplot(bad_df["tempo"], color='r', label="dislikes").set_title("Tempo")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(good_df["time_signature"], color='b', label="likes")
sns.distplot(bad_df["time_signature"], color='r', label="dislikes").set_title("Tempo")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(good_df["energy"], color='b', label="likes", bins= 20)
sns.distplot(bad_df["energy"], color='r', label="dislikes", bins = 20).set_title("Energy")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## Exploration

# %% [markdown]
# Let's add on other features that can possibily be useful  for our model. We can go back to look at other traits of our songs, like how popular or explicit a track is. Try playing around with these features to see if there's any noticeable difference between our liked songs and our disliked songs.

# %%
def find_popularity(userID, playlistID):
    playlist = sp.user_playlist(userID, playlistID)
    songs = playlist["tracks"]["items"]
    popularity = []
    for i in songs:
        popularity.append(i["track"]["popularity"])
    return popularity

# %%
good_popularity = find_popularity(username, good_id)
bad_popularity = find_popularity(username, bad_id)

# %% [markdown]
# Let's add these new features to our dataframe columns and look at the histogram of each dataframe.

# %%
good_df["popularity"] = good_popularity
bad_df["popularity"] = bad_popularity
bad_df.head()
# Out:
#                               acousticness  danceability  duration_ms  energy  \
# Bouncin                            0.31400         0.713       195429   0.611
# Throwin' Elbows                    0.00314         0.580       182400   0.940
# All Star                           0.03190         0.731       200373   0.861
# Seven Million (feat. Future)       0.05100         0.886       182491   0.629
# through the late night             0.36000         0.744       286236   0.589
#
#                               instrumentalness  key  liveness  loudness  mode  \
# Bouncin                               0.000000    1    0.1170    -6.702     0
# Throwin' Elbows                       0.042600    2    0.1130    -3.038     1
# All Star                              0.000000   11    0.0829    -5.881     1
# Seven Million (feat. Future)          0.000008    1    0.1210    -4.404     0
# through the late night                0.000000    5    0.1190    -1.218     0
#
#                               speechiness    tempo  time_signature  valence  \
# Bouncin                            0.2410  140.061               4    0.793
# Throwin' Elbows                    0.5670  149.990               4    0.362
# All Star                           0.0323  104.034               4    0.780
# Seven Million (feat. Future)       0.3060  158.002               4    0.487
# through the late night             0.0359  127.051               4    0.242
#
#                               popularity
# Bouncin                               50
# Throwin' Elbows                       54
# All Star                              80
# Seven Million (feat. Future)          63
# through the late night                70

# %%
sns.distplot(good_df["popularity"], color='b', label="likes")
sns.distplot(bad_df["popularity"], color='r', label="dislikes").set_title("Popularity")
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# Now let's look at how many explicit songs are in each playlist.

# %%
def find_explicit(userID, playlistID):
    playlist = sp.user_playlist(userID, playlistID)
    songs = playlist["tracks"]["items"]
    popularity = []
    for i in songs:
        popularity.append(i["track"]["explicit"])
    return popularity

# %%
good_explicit = find_explicit(username, good_id)
bad_explicit = find_explicit(username, bad_id)

# %%
good_df["explicit"] = good_explicit
bad_df["explicit"] = bad_explicit
bad_df.head()
# Out:
#                               acousticness  danceability  duration_ms  energy  \
# Bouncin                            0.31400         0.713       195429   0.611
# Throwin' Elbows                    0.00314         0.580       182400   0.940
# All Star                           0.03190         0.731       200373   0.861
# Seven Million (feat. Future)       0.05100         0.886       182491   0.629
# through the late night             0.36000         0.744       286236   0.589
#
#                               instrumentalness  key  liveness  loudness  mode  \
# Bouncin                               0.000000    1    0.1170    -6.702     0
# Throwin' Elbows                       0.042600    2    0.1130    -3.038     1
# All Star                              0.000000   11    0.0829    -5.881     1
# Seven Million (feat. Future)          0.000008    1    0.1210    -4.404     0
# through the late night                0.000000    5    0.1190    -1.218     0
#
#                               speechiness    tempo  time_signature  valence  \
# Bouncin                            0.2410  140.061               4    0.793
# Throwin' Elbows                    0.5670  149.990               4    0.362
# All Star                           0.0323  104.034               4    0.780
# Seven Million (feat. Future)       0.3060  158.002               4    0.487
# through the late night             0.0359  127.051               4    0.242
#
#                               popularity  explicit
# Bouncin                               50      True
# Throwin' Elbows                       54     False
# All Star                              80     False
# Seven Million (feat. Future)          63      True
# through the late night                70      True

# %% [markdown]
# ## Adding Our Binary Classification

# %% [markdown]
# Now that we've got the features we want, we want to create a column for our binary classification. In this scenario, 0's stand for songs we dislike, and 1's stand for songs we like. After we create these columns, let's join our good and bad dataframes together to get one large dataframe of all of the songs we observed.

# %%
#add array of 1's to good_df
good_df["like/dislike"] = [1] * (len(good_df))
bad_df["like/dislike"] = [0] * (len(bad_df))
good_df.head()
# Out:
#                        acousticness  danceability  duration_ms  energy  \
# Day 1 ◑                       0.210         0.503       233601   0.581
# Midsummer Madness             0.359         0.409       280842   0.678
# I Like U                      0.071         0.480       267733   0.526
# Paris in the Rain             0.771         0.426       204712   0.408
# Heebiejeebies - Bonus         0.419         0.766       220160   0.500
#
#                        instrumentalness  key  liveness  loudness  mode  \
# Day 1 ◑                        0.000708    6    0.2570    -7.007     1
# Midsummer Madness              0.000005    9    0.1670    -7.731     1
# I Like U                       0.000000    5    0.0879    -7.099     1
# Paris in the Rain              0.000008    3    0.3940    -9.419     1
# Heebiejeebies - Bonus          0.000000    1    0.1080    -7.626     1
#
#                        speechiness    tempo  time_signature  valence  \
# Day 1 ◑                     0.0881   94.555               4    0.633
# Midsummer Madness           0.0878   89.968               4    0.168
# I Like U                    0.2750  199.662               3    0.374
# Paris in the Rain           0.0524   76.309               4    0.528
# Heebiejeebies - Bonus       0.1520  107.045               4    0.495
#
#                        popularity  explicit  like/dislike
# Day 1 ◑                        64     False             1
# Midsummer Madness              78      True             1
# I Like U                       62      True             1
# Paris in the Rain              73     False             1
# Heebiejeebies - Bonus          72      True             1

# %%
#concatenate good_df and bad_df to one large dataframe
all_songs = pd.concat([good_df, bad_df])
all_songs
# Out:
#                                          acousticness  danceability  \
# Day 1 ◑                                      0.210000         0.503
# Midsummer Madness                            0.359000         0.409
# I Like U                                     0.071000         0.480
# Paris in the Rain                            0.771000         0.426
# Heebiejeebies - Bonus                        0.419000         0.766
# Plastic (Mid-City Island Version)            0.741000         0.457
# Fantasy                                      0.355000         0.686
# Sunday Candy                                 0.530000         0.511
# Lemonade - Ukulele Version                   0.868000         0.546
# Chivalry Is Dead                             0.021400         0.690
# Down For You (feat. BJ The Chicago Kid)      0.456000         0.479
# Crush                                        0.340000         0.670
# Niggas                                       0.041000         0.455
# Cranes in the Sky                            0.408000         0.719
# Hope                                         0.196000         0.822
# WINDOWS FT. RICK RO$$                      -3.639     1       0.3540  160.158
# Jekyll and Hyde                            -4.157     1       0.1130  155.017
# You Want a Battle? (Here's a War)          -4.075     0       0.0854  134.335
# Satan Is Real                              -4.551     1       0.0775  101.590
# Happy Song                                 -3.433     1       0.0645  171.931
# The Heart From Your Hate                   -4.659     0       0.0635  113.043
# Looking Down the Barrel of Today           -4.710     1       0.0812  180.065
# Crushed                                    -4.569     1       0.1150   84.996
# Silvera                                    -4.348     1       0.0720  137.052
# The End of Heartache                       -3.569     0       0.1110  124.001
# The Sound Of Truth                         -4.084     0       0.1200  165.018
# Is There Anybody out There?                -3.883     1       0.2260  177.940
# Wash It All Away                           -3.100     1       0.0738  123.576
# Vice Grip                                  -3.229     0       0.0838  124.041
# My Curse                                   -2.908     0       0.0663  177.018
# Your Betrayal                              -4.410     0       0.0747  134.003
# Codename X - Virtual Riot Remix            -3.222     1       0.0940  112.449
# Party Drink Smoke                          -4.364     1       0.2320   74.984
# Resurrected - Original Mix                 -2.049     1       0.0643  140.023
# Like A Bitch - Extended Mix                -0.846     1       0.0997  149.985
# Get With The Program Ft. O.V               -0.635     0       0.0558  145.033
# Lights Out                                 -2.681     1       0.0381  149.978
# Invaders                                   -1.480     1       0.1360  145.034
# Take Off                                   -3.253     1       0.1370  149.909
# Jotaro                                     -1.908     0       0.0351  140.123
# 100s                                       -1.471     0       0.0550  149.852
# Blast Ya (feat. Barrington Levy)           -0.819     0       0.2510  149.935
#
#                                          time_signature  valence  popularity  \
# Day 1 ◑                                               4    0.633          64
# Midsummer Madness                                     4    0.168          78
# I Like U                                              3    0.374          62
# Paris in the Rain                                     4    0.528          73
# Heebiejeebies - Bonus                                 4    0.495          72
# Plastic (Mid-City Island Version)                     4    0.180          52
# Fantasy                                               4    0.344          47
# Sunday Candy                                          4    0.554          68
# Lemonade - Ukulele Version                            4    0.593           3
# Chivalry Is Dead                                      4    0.661           0
# Down For You (feat. BJ The Chicago Kid)               5    0.347          53
# Crush                                                 4    0.384           8
# Niggas                                                4    0.413          54
# Cranes in the Sky                                     4    0.465          63
# Hope                                                  4    0.281          57
# Falling                                               4    0.508          45
# Secrets (feat. Sam Fischer)                           4    0.690          35
# Thinkin Bout You                                      4    0.203          70
# That's What I Like                                    4    0.860          83
# Morning                                               3    0.344          67
# You & Me                                              4    0.616          60
# Heard 'Em Say                                         4    0.569          60
# Better Together                                       4    0.518          64
# Love Yourself                                         4    0.545          82
# Company                                               4    0.420          70
# Purpose                                               4    0.302          70
# Weak                                                  4    0.656          67
# Lay Me Down                                           4    0.326          76
# Location                                              4    0.326          82
# Feel Good (feat. Daya) - Acoustic                     4    0.231          43
# ...                                                 ...      ...         ...
# I WARE HOUSE                                          4    0.300          52
# HOT DRUM                                              4    0.156          52
# THE BOX                                               4    0.282          49
# WINDOWS FT. RICK RO$$                                 4    0.471          48
